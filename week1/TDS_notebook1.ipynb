# %% [markdown]
# # TDS Week1 Notes and books

# %% [markdown]
# ## Discover the data

# %% [markdown]
# Before we begin the data science journey, you first need the data set. And to get the data set, you need to know where it is. This is what we will be covering in the first module.
#
# How do you discover data? There are three things that you will learn in this module.
#
# The first is, what are the different sources of data sets? Where can you find them?<br>
# The second is, what are the different kinds of data sets? Structured, unstructured and semi-structured.<br>
# Third, in each data set, what are the different kinds of values that you will find?<br>
# This will give you a sense of locating the kind of data set that you want, either on the internet or within your organization or even within your phones.

# %% [markdown]
# ## Sources of Data

# %% [markdown]
# Lecture provided examples of different sources of data.
#
# [Awesome public datasets](https://github.com/awesomedata/awesome-public-datasets) <br>
# [Google dataset search](https://datasetsearch.research.google.com/) <br>
# [Kaggle datasets](https://www.kaggle.com/datasets/) <br>
# [US Gov datasets](https://data.gov/) <br>
# [Indian Gov datasets](https://www.data.gov.in/)
# [Datameet](https://datameet.org/)

# %% [markdown]
# ## Types of datasets

# %% [markdown]
# - Structured data has a schema: Databases, Spreadsheets, Forms, Shapefiles
# - Semi-structured data has a flexible schema: JSON, HTML, Email
# - Unstructured data has no schema: Text, Images, Audio, Video
# - [DBF opener](https://dbfopener.com/)
# - [MapShaper](https://mapshaper.org/) lets you view Shapefiles

# %% [markdown]
# ## Types of values

# %% [markdown]
# - Categorical values may be:
#   - Boolean: True or False
#   - Unordered: No order, like colors
#   - Ordered: Order, like ratings
#   - Cyclical: Like days of the week
#   - Unstructured: Like names, images
# - Numerical values may be:
#   - Integer: You can add or subtract
#   - Real: You can multiply or divide
# - Composite values have an internal structure
#   - Temporal: Date, Time
#   - Spatial: Latitude, Longitude, Shapefiles
#   - Structured: JSON, XML with schema
#   - Specialized: IP addresses, URLs, Email addresses, Phone numbers, etc.

# %% [markdown]
# # Graded Assignment 1:

# %% [markdown]
# Graded Assignment 1
#
# The due date for submitting this assignment has passed.
#
# Due on 2024-06-16, 23:59 IST.
#
# You may submit any number of times before the due date. The final
# submission will be considered for grading.
#
# You have last submitted on: 2024-06-05, 21:14 IST
#
# Search for the "World Happiness Report" dataset on Kaggle. Find the official one, by "Sustainable Development Solutions Network". What was the GDP per capita of Myanmar in 2018?
#
#
#     0.682
#
#     0.578
#
#     0.365
#
#     0.372
#
#     Yes, the answer is correct.
#
#     Score: 1
#
#     Accepted Answers:
#
#     0.682
#
# Search for the "World Happiness Report" dataset on Kaggle. Find the official one, by "Sustainable Development Solutions Network". What was the Economy (GDP per Capita) of Hong Kong in 2015?
#
#     1.38604
#
#     0.22269
#
#     1.78555
#
#     0.69702
#
#     Yes, the answer is correct.
#
#     Score: 1
#
#     Accepted Answers:
#
#     1.38604
#
# What is the official data portal of Malta?
#
#     data.mt/
#
#     data.gov.mt/
#
#     egov.mt/
#
#     data.co.mt/
#
#     Yes, the answer is correct.
#
#     Score: 1
#
#     Accepted Answers:
#
#     data.gov.mt/
#
# What is the official data portal of Trinidad and Tobago?
#
#     data.gov.tt/
#
#     data.co.tt/
#
#     data.tt/
#
#     egov.tt/
#
#     Yes, the answer is correct.
#
#     Score: 1
#
#     Accepted Answers:
#
#     data.gov.tt/
#
# What is the official data portal of United Nations?
#
#     stats.un.org/
#
#     data.un.org/
#
#     data.org/
#
#     data.un.com/
#
#     Yes, the answer is correct.
#
#     Score: 1
#
#     Accepted Answers:
#
#     data.un.org/
#
# Classify into structured, semi-structured or unstructured: Audio book recordings. Focus on the content, not the file/storage format.
#
#     Structured
#
#     Semi-structured
#
#     Unstructured
#
#     Yes, the answer is correct.
#
#     Score: 1
#
#     Accepted Answers:
#
#     Unstructured
#
# Classify into structured, semi-structured or unstructured: Medical records in HL7 format. Focus on the content, not the file/storage format.
#
#     Unstructured
#
#     Semi-structured
#
#     Structured
#
#     Yes, the answer is correct.
#
#     Score: 1
#
#     Accepted Answers:
#
#     Structured
#
# Which of these types of values best describes Birthdate?
#
#     Categorical - Ordered
#
#     Numerical - Integer
#
#     Categorical - Unordered
#
#     Composite - Temporal
#
#     Yes, the answer is correct.
#
#     Score: 1
#
#     Accepted Answers:
#
#     Composite - Temporal
#
# Which of these types of values best describes Filename?
#
#     Numerical - Real
#
#     Composite - Specialized
#
#     Numerical - Integer
#
#     Categorical - Unordered
#
#     No, the answer is incorrect.
#
#     Score: 0
#
#     Accepted Answers:
#
#     Composite - Specialized
#
# Which of these types of values best describes City Name?
#
#     Categorical - Unordered
#
#     Numerical - Integer
#
#     Composite - Temporal
#
#     Numerical - Real
#
#     Yes, the answer is correct.
#
#     Score: 1
#
#     Accepted Answers:
#
#     Categorical - Unordered
